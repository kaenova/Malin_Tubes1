# %%
# Optional
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install scikit-learn-extra

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df = pd.read_csv("/content/drive/MyDrive/Semester 5/Pembelajaran Mesin/Tugas Besar/Dataset/Processed/kendaraan_train_explored_balance.csv")

# %%
df['Tertarik'].unique()
# Out:
# array([0, 1])

# %%
labels = np.array(df['Tertarik'].to_list())

# %%
df_no_labels = df.drop(columns="Tertarik", axis=1)

# %%
df_no_ids = df_no_labels.drop(columns="id", axis=1)

# %%
df_no_ids
# Out:
#        Jenis_Kelamin  Umur  SIM  ...    Premi  Kanal_Penjualan  Lama_Berlangganan
# 0                  1    34    1  ...   2630.0            156.0              271.0
# 1                  0    46    1  ...  58797.0             26.0              246.0
# 2                  1    60    1  ...  30088.0            124.0              131.0
# 3                  0    34    1  ...   2630.0            138.0               21.0
# 4                  0    32    1  ...   2630.0            156.0               32.0
# ...              ...   ...  ...  ...      ...              ...                ...
# 41591              1    40    1  ...  54930.0            156.0              183.0
# 41592              1    50    1  ...  24116.0            154.0               22.0
# 41593              0    30    1  ...  28029.0            152.0               97.0
# 41594              1    22    1  ...  24724.0            152.0              206.0
# ...

# %%
training_data = df_no_ids.to_numpy()

# %% [markdown]
# # K - Means

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2).fit(training_data)

# %%
prediction = kmeans.predict(training_data)

# %%
import sklearn

# %%
sklearn.metrics.accuracy_score(labels, prediction)
# Out:
# 0.49759592268487357

# %% [markdown]
# # K - Medoids (not Good for big Data >30.000 x 10)

# %%
input = training_data[:30000]
output = labels[:30000]

# %%
from sklearn_extra.cluster import KMedoids

# %%
kmedoids = KMedoids(n_clusters=2, max_iter=1000).fit(input)

# %%
prediction = kmedoids.predict(input)

# %%
sklearn.metrics.accuracy_score(output, prediction)
# Out:
# 0.5292333333333333

# %% [markdown]
# # Agglomerative Clustering (not Good for Big Data)

# %%
input = training_data[:30000]
output = labels[:30000]

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
prediction = AgglomerativeClustering(n_clusters=2).fit_predict(input, output)

# %%
sklearn.metrics.accuracy_score(output, prediction)
# Out:
# 0.5064

# %% [markdown]
# # Birch (no good big data)

# %%
input = training_data[:30000]
output = labels[:30000]

# %%
from sklearn.cluster import Birch

# %%
prediction = Birch(n_clusters=2).fit_predict(input, output)
sklearn.metrics.accuracy_score(output, prediction)
# Out:
# 0.5064

# %% [markdown]
# # Spectral Clustering

# %%
input = training_data[:5000]
output = labels[:5000]

# %%
from sklearn.cluster import SpectralClustering

# %%
prediction = SpectralClustering(n_clusters=2).fit_predict(input, output)
sklearn.metrics.accuracy_score(output, prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_spectral_embedding.py:261: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   "Graph is not fully connected, spectral embedding may not work as expected."
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-02080e987deb> in <module>()
# ----> 1 prediction = SpectralClustering(n_clusters=2).fit_predict(input, output)
#       2 sklearn.metrics.accuracy_score(output, prediction)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_spectral.py in fit_predict(self, X, y)
#     640             Cluster labels.
#     641         """
# --> 642         return super().fit_predict(X, y)
#     643
#     644     def _more_tags(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_predict(self, X, y)
# ...

# %% [markdown]
# # Gaussian Mixture

# %%
from sklearn.mixture import GaussianMixture

# %%
prediction = GaussianMixture(n_components=2).fit_predict(input, output)
sklearn.metrics.accuracy_score(output, prediction)
# Out:
# 0.5052
